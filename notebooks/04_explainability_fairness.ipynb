# %% [markdown]
# # 04 — Explainability, fairness and governance
# A strong offline score is only the beginning for a credit-risk system.

# %%
governance_checks = {
 'explainability':['global feature effects','local adverse-action reasons'],
 'fairness':['subgroup recall','false-positive rate','calibration'],
 'operations':['data drift','performance drift','override monitoring'],
 'controls':['legal review','human appeal','model versioning']}
governance_checks

# %% [markdown]
# Protected attributes may be required for a controlled fairness audit even when they must not be decision features. Legal and domain review determines the applicable process.
