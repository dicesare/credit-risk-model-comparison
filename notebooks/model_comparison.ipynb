# %% [markdown]
# # Credit Risk Model Comparison
# Compare an interpretable baseline and a tree ensemble with metrics appropriate for an imbalanced target. No applicant data is embedded.

# %%
from pathlib import Path
import pandas as pd
from credit_risk import build_model_pipeline, evaluate_binary_predictions, split_features_target

DATA_PATH = Path('../data/raw/application_data.csv')

# %% [markdown]
# ## Evaluation contract
# Use a stratified hold-out set. Report ROC-AUC, average precision and recall, then discuss the business cost of the selected threshold.

# %%
# data = pd.read_csv(DATA_PATH)
# X, y = split_features_target(data)
# model = build_model_pipeline(X, model='logistic')
