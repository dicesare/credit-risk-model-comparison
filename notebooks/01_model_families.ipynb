# %% [markdown]
# # 01 — Compare model families
# Use the same split, preprocessing and metrics for every candidate.

# %%
candidates = {
 'logistic_regression':'interpretable linear baseline',
 'knn':'local non-linear baseline',
 'decision_tree':'interpretable rules',
 'random_forest':'bagged ensemble',
 'gradient_boosting':'boosted ensemble'}
candidates

# %% [markdown]
# Prefer stratified cross-validation and out-of-fold predictions. Compare average precision and minority-class recall alongside ROC-AUC.
