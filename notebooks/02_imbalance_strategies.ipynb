# %% [markdown]
# # 02 — Imbalance strategies
# Compare cost-sensitive learning with resampling without contaminating validation data.

# %%
strategies = [
 {'name':'class_weight','leakage_rule':'weight training loss only'},
 {'name':'SMOTE','leakage_rule':'resample inside each training fold'},
 {'name':'none','leakage_rule':'baseline for comparison'}]
strategies

# %% [markdown]
# Never oversample before the train/test split. Report calibration because resampling can distort predicted probabilities.
